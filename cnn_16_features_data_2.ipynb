# %%
pip install xlrd==1.2.0 ### ######
# Out:
# Collecting xlrd==1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 34.2 MB/s
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# Successfully installed xlrd-1.2.0

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 34.7 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.3

# %%
name_file = "CNN_dataset_2"

# %%
from sklearn import metrics , cross_decomposition, model_selection
from sklearn.model_selection import cross_validate
from scipy.signal import savgol_filter
import pandas as pd
import numpy as np
import xlrd
import xlsxwriter
from sklearn.preprocessing import StandardScaler, MinMaxScaler #for calculate SNV
import time
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler ## for calculate SNV
from sklearn.model_selection import train_test_split as split
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut 
from sys import stdout
import re
from keras.layers.advanced_activations import LeakyReLU
from sklearn.model_selection import train_test_split   
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from keras.layers import Input
from keras.utils import np_utils

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ write name of output file name 
time1=time.time()

# ================= import data
workbook = xlrd.open_workbook("/content/IG-Dataset18_11.xlsx","rb")
sheets = workbook.sheet_names()
sheet_num=1  ## add sheet number # 5
sh = workbook.sheet_by_name(sheets[(sheet_num)-1])
n_cols=0 ##number of colum you have to delet from the front
n_rows=0 ##number of rows you have to delet from the front 
m_cols=0 ## number of colum you have to delet from the end
m_rows=0 ## number of rows you have to delet from the end
M_rows=sh.nrows-m_rows
M_cols=sh.ncols-m_cols
required_data = []
for rownum in range(n_rows,M_rows):
    row_valaues = sh.row_values(rownum)
    required_data.append(row_valaues[n_cols:M_cols])
Required_data=np.asarray(required_data)
X=Required_data[1:257674,0:16].astype(float)  #  25194 # 82334  ( 4:41 & 1:40)
X= np.array (X)

Y=Required_data[1:257674,17:18].astype(float).ravel()    # (42:43  & 41:42)
print(X.shape)

bands = Required_data[0:1, 0:16]      # ( 4:41 & 1:40)
bands= np.array (bands)
#===============
X_train, X_test, y_train, y_test = split(X, Y, test_size=(0.20), random_state=0)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
# ==============================================

nb_classes = len (np.unique( y_train ))
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

X_train = X_train.reshape(X_train.shape[0], 1, 16, 1)   #Reshape for lstm - should work!!
X_test= X_test.reshape(X_test.shape[0], 1, 16, 1)

print('class', nb_classes)
# Out:
# (257673, 16)
# class 2

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, Flatten, MaxPooling2D,BatchNormalization
from keras.layers import LSTM,TimeDistributed,Conv1D,MaxPooling1D
from keras.layers import Dense, Dropout, Flatten
from keras import models
from keras import layers
from keras.models import Model

CNN_model = Sequential()
CNN_model.add(Conv2D(512, kernel_size=(3, 3),activation='tanh',padding='same',input_shape=(1,16,1)))
CNN_model.add(BatchNormalization())
CNN_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
CNN_model.add(Conv2D(256, (3, 3), activation='tanh',padding='same'))
CNN_model.add(BatchNormalization())
CNN_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
CNN_model.add(Conv2D(128, (3, 3), activation='tanh',padding='same'))
CNN_model.add(Conv2D(128, (3, 3), activation='tanh',padding='same'))
CNN_model.add(BatchNormalization())
CNN_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
CNN_model.add(Conv2D(64, (3, 3), activation='tanh',padding='same')) #~~~~~~~~~~~   512
CNN_model.add(Conv2D(64, (3, 3), activation='tanh',padding='same')) #~~~~~~~~~~~   512
CNN_model.add(Conv2D(64, (3, 3), activation='tanh',padding='same')) #~~~~~~~~~~~   512
CNN_model.add(BatchNormalization())
CNN_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
CNN_model.add(Flatten())
CNN_model.add(Dense(nb_classes, activation='softmax'))

# %%
from keras.utils.vis_utils import plot_model
plot_model(CNN_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger

CNN_model.compile(loss=keras.losses.binary_crossentropy,optimizer='Adamax',metrics=['accuracy'])  

csv_logger = CSVLogger('training.log', separator=',', append=False)
mc = ModelCheckpoint(name_file +'.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
cnn11 = CNN_model.fit(X_train,Y_train, batch_size=300, epochs=500, validation_data=(X_test ,Y_test), callbacks=[mc,csv_logger])
print (("Training time=", time.time()-time1))
np.save("CNN_data_2_@history", cnn11.history)
# Out:
# Epoch 1/500
# 688/688 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.8756
# Epoch 1: val_loss improved from inf to 0.22948, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 24s 17ms/step - loss: 0.2629 - accuracy: 0.8756 - val_loss: 0.2295 - val_accuracy: 0.8940
# Epoch 2/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.2010 - accuracy: 0.9032
# Epoch 2: val_loss did not improve from 0.22948
# 688/688 [==============================] - 10s 15ms/step - loss: 0.2010 - accuracy: 0.9032 - val_loss: 0.3702 - val_accuracy: 0.7657
# Epoch 3/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1820 - accuracy: 0.9104
# Epoch 3: val_loss did not improve from 0.22948
# 688/688 [==============================] - 10s 15ms/step - loss: 0.1820 - accuracy: 0.9104 - val_loss: 0.2709 - val_accuracy: 0.8499
# Epoch 4/500
# 687/688 [============================>.] - ETA: 0s - loss: 0.1690 - accuracy: 0.9168
# Epoch 4: val_loss improved from 0.22948 to 0.19737, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1690 - accuracy: 0.9168 - val_loss: 0.1974 - val_accuracy: 0.8918
# Epoch 5/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1607 - accuracy: 0.9209
# Epoch 5: val_loss did not improve from 0.19737
# 688/688 [==============================] - 10s 15ms/step - loss: 0.1607 - accuracy: 0.9209 - val_loss: 0.3271 - val_accuracy: 0.8572
# Epoch 6/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1539 - accuracy: 0.9248
# Epoch 6: val_loss did not improve from 0.19737
# 688/688 [==============================] - 10s 15ms/step - loss: 0.1540 - accuracy: 0.9248 - val_loss: 0.2560 - val_accuracy: 0.8618
# Epoch 7/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1493 - accuracy: 0.9273
# Epoch 7: val_loss did not improve from 0.19737
# 688/688 [==============================] - 10s 15ms/step - loss: 0.1493 - accuracy: 0.9273 - val_loss: 0.3002 - val_accuracy: 0.8089
# Epoch 8/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1460 - accuracy: 0.9285
# Epoch 8: val_loss improved from 0.19737 to 0.16435, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1459 - accuracy: 0.9285 - val_loss: 0.1644 - val_accuracy: 0.9279
# Epoch 9/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9295
# Epoch 9: val_loss did not improve from 0.16435
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1437 - accuracy: 0.9295 - val_loss: 0.2395 - val_accuracy: 0.8552
# Epoch 10/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1425 - accuracy: 0.9299
# Epoch 10: val_loss did not improve from 0.16435
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1425 - accuracy: 0.9299 - val_loss: 0.2429 - val_accuracy: 0.8538
# Epoch 11/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1400 - accuracy: 0.9312
# Epoch 11: val_loss did not improve from 0.16435
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1400 - accuracy: 0.9312 - val_loss: 0.1691 - val_accuracy: 0.9299
# Epoch 12/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1390 - accuracy: 0.9315
# Epoch 12: val_loss did not improve from 0.16435
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1390 - accuracy: 0.9315 - val_loss: 0.1797 - val_accuracy: 0.9016
# Epoch 13/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1372 - accuracy: 0.9314
# Epoch 13: val_loss did not improve from 0.16435
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1372 - accuracy: 0.9315 - val_loss: 0.3831 - val_accuracy: 0.8747
# Epoch 14/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1353 - accuracy: 0.9322
# Epoch 14: val_loss did not improve from 0.16435
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1354 - accuracy: 0.9322 - val_loss: 0.2347 - val_accuracy: 0.9138
# Epoch 15/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9329
# Epoch 15: val_loss did not improve from 0.16435
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1342 - accuracy: 0.9329 - val_loss: 0.2083 - val_accuracy: 0.9151
# Epoch 16/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9332
# Epoch 16: val_loss improved from 0.16435 to 0.15325, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1337 - accuracy: 0.9331 - val_loss: 0.1532 - val_accuracy: 0.9279
# Epoch 17/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9332
# Epoch 17: val_loss improved from 0.15325 to 0.13867, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1326 - accuracy: 0.9332 - val_loss: 0.1387 - val_accuracy: 0.9318
# Epoch 18/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1317 - accuracy: 0.9334
# Epoch 18: val_loss did not improve from 0.13867
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1317 - accuracy: 0.9334 - val_loss: 0.2489 - val_accuracy: 0.8830
# Epoch 19/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1312 - accuracy: 0.9340
# Epoch 19: val_loss did not improve from 0.13867
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1312 - accuracy: 0.9340 - val_loss: 0.2105 - val_accuracy: 0.8883
# Epoch 20/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1298 - accuracy: 0.9346
# Epoch 20: val_loss did not improve from 0.13867
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1299 - accuracy: 0.9346 - val_loss: 0.1662 - val_accuracy: 0.9318
# Epoch 21/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1289 - accuracy: 0.9347
# Epoch 21: val_loss improved from 0.13867 to 0.12938, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1288 - accuracy: 0.9347 - val_loss: 0.1294 - val_accuracy: 0.9353
# Epoch 22/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.9354
# Epoch 22: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1280 - accuracy: 0.9354 - val_loss: 0.1692 - val_accuracy: 0.9163
# Epoch 23/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9355
# Epoch 23: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1272 - accuracy: 0.9355 - val_loss: 0.1354 - val_accuracy: 0.9368
# Epoch 24/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1263 - accuracy: 0.9364
# Epoch 24: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1263 - accuracy: 0.9364 - val_loss: 0.1370 - val_accuracy: 0.9318
# Epoch 25/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1252 - accuracy: 0.9368
# Epoch 25: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1252 - accuracy: 0.9368 - val_loss: 0.1312 - val_accuracy: 0.9352
# Epoch 26/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1248 - accuracy: 0.9375
# Epoch 26: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1249 - accuracy: 0.9375 - val_loss: 0.1938 - val_accuracy: 0.9044
# Epoch 27/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1242 - accuracy: 0.9375
# Epoch 27: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1242 - accuracy: 0.9375 - val_loss: 0.2896 - val_accuracy: 0.8768
# Epoch 28/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1240 - accuracy: 0.9374
# Epoch 28: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1240 - accuracy: 0.9374 - val_loss: 0.2268 - val_accuracy: 0.8771
# Epoch 29/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1231 - accuracy: 0.9377
# Epoch 29: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1232 - accuracy: 0.9377 - val_loss: 0.2557 - val_accuracy: 0.8906
# Epoch 30/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1227 - accuracy: 0.9386
# Epoch 30: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1227 - accuracy: 0.9386 - val_loss: 0.1493 - val_accuracy: 0.9350
# Epoch 31/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1221 - accuracy: 0.9386
# Epoch 31: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1221 - accuracy: 0.9386 - val_loss: 0.1386 - val_accuracy: 0.9369
# Epoch 32/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9391
# Epoch 32: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1216 - accuracy: 0.9391 - val_loss: 0.2094 - val_accuracy: 0.8898
# Epoch 33/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9390
# Epoch 33: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1216 - accuracy: 0.9390 - val_loss: 0.1424 - val_accuracy: 0.9339
# Epoch 34/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9389
# Epoch 34: val_loss did not improve from 0.12938
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1216 - accuracy: 0.9389 - val_loss: 0.1909 - val_accuracy: 0.9046
# Epoch 35/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1215 - accuracy: 0.9386
# Epoch 35: val_loss improved from 0.12938 to 0.12886, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1215 - accuracy: 0.9386 - val_loss: 0.1289 - val_accuracy: 0.9355
# Epoch 36/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1202 - accuracy: 0.9394
# Epoch 36: val_loss did not improve from 0.12886
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1203 - accuracy: 0.9394 - val_loss: 0.2412 - val_accuracy: 0.9148
# Epoch 37/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1201 - accuracy: 0.9400
# Epoch 37: val_loss did not improve from 0.12886
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1201 - accuracy: 0.9400 - val_loss: 0.3003 - val_accuracy: 0.8989
# Epoch 38/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1193 - accuracy: 0.9406
# Epoch 38: val_loss did not improve from 0.12886
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1193 - accuracy: 0.9405 - val_loss: 0.1542 - val_accuracy: 0.9318
# Epoch 39/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1196 - accuracy: 0.9404
# Epoch 39: val_loss did not improve from 0.12886
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1197 - accuracy: 0.9403 - val_loss: 0.1306 - val_accuracy: 0.9361
# Epoch 40/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1188 - accuracy: 0.9404
# Epoch 40: val_loss did not improve from 0.12886
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1188 - accuracy: 0.9405 - val_loss: 0.1556 - val_accuracy: 0.9335
# Epoch 41/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1194 - accuracy: 0.9399
# Epoch 41: val_loss did not improve from 0.12886
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1194 - accuracy: 0.9399 - val_loss: 0.1442 - val_accuracy: 0.9279
# Epoch 42/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1188 - accuracy: 0.9407
# Epoch 42: val_loss improved from 0.12886 to 0.12531, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1187 - accuracy: 0.9407 - val_loss: 0.1253 - val_accuracy: 0.9371
# Epoch 43/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9411
# Epoch 43: val_loss improved from 0.12531 to 0.12202, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1182 - accuracy: 0.9411 - val_loss: 0.1220 - val_accuracy: 0.9397
# Epoch 44/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9410
# Epoch 44: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1179 - accuracy: 0.9410 - val_loss: 0.1260 - val_accuracy: 0.9364
# Epoch 45/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9410
# Epoch 45: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1177 - accuracy: 0.9410 - val_loss: 0.1364 - val_accuracy: 0.9371
# Epoch 46/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.9413
# Epoch 46: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1172 - accuracy: 0.9413 - val_loss: 0.1417 - val_accuracy: 0.9279
# Epoch 47/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9415
# Epoch 47: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1169 - accuracy: 0.9415 - val_loss: 0.1707 - val_accuracy: 0.9052
# Epoch 48/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1167 - accuracy: 0.9413
# Epoch 48: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1166 - accuracy: 0.9413 - val_loss: 0.1320 - val_accuracy: 0.9387
# Epoch 49/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1163 - accuracy: 0.9418
# Epoch 49: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1163 - accuracy: 0.9418 - val_loss: 0.1262 - val_accuracy: 0.9366
# Epoch 50/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1163 - accuracy: 0.9417
# Epoch 50: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1163 - accuracy: 0.9416 - val_loss: 0.1884 - val_accuracy: 0.9185
# Epoch 51/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1153 - accuracy: 0.9424
# Epoch 51: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1154 - accuracy: 0.9424 - val_loss: 0.3119 - val_accuracy: 0.8837
# Epoch 52/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1150 - accuracy: 0.9430
# Epoch 52: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1150 - accuracy: 0.9430 - val_loss: 0.1326 - val_accuracy: 0.9349
# Epoch 53/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9424
# Epoch 53: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1151 - accuracy: 0.9424 - val_loss: 0.1709 - val_accuracy: 0.9235
# Epoch 54/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1149 - accuracy: 0.9425
# Epoch 54: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1150 - accuracy: 0.9425 - val_loss: 0.1245 - val_accuracy: 0.9383
# Epoch 55/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1149 - accuracy: 0.9425
# Epoch 55: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1148 - accuracy: 0.9425 - val_loss: 0.2341 - val_accuracy: 0.8875
# Epoch 56/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1150 - accuracy: 0.9423
# Epoch 56: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1149 - accuracy: 0.9424 - val_loss: 0.2341 - val_accuracy: 0.8998
# Epoch 57/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1142 - accuracy: 0.9431
# Epoch 57: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1142 - accuracy: 0.9431 - val_loss: 0.1553 - val_accuracy: 0.9208
# Epoch 58/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1138 - accuracy: 0.9437
# Epoch 58: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1138 - accuracy: 0.9437 - val_loss: 0.1292 - val_accuracy: 0.9384
# Epoch 59/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1134 - accuracy: 0.9436
# Epoch 59: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1134 - accuracy: 0.9436 - val_loss: 0.1922 - val_accuracy: 0.9200
# Epoch 60/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1132 - accuracy: 0.9437
# Epoch 60: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1131 - accuracy: 0.9438 - val_loss: 0.1957 - val_accuracy: 0.9119
# Epoch 61/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1129 - accuracy: 0.9436
# Epoch 61: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1129 - accuracy: 0.9436 - val_loss: 0.1659 - val_accuracy: 0.9190
# Epoch 62/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.1124 - accuracy: 0.9440
# Epoch 62: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1124 - accuracy: 0.9440 - val_loss: 0.1454 - val_accuracy: 0.9325
# Epoch 63/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1125 - accuracy: 0.9439
# Epoch 63: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1124 - accuracy: 0.9439 - val_loss: 0.1718 - val_accuracy: 0.9213
# Epoch 64/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9444
# Epoch 64: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1120 - accuracy: 0.9444 - val_loss: 0.1417 - val_accuracy: 0.9320
# Epoch 65/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9442
# Epoch 65: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1120 - accuracy: 0.9442 - val_loss: 0.1516 - val_accuracy: 0.9328
# Epoch 66/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1112 - accuracy: 0.9444
# Epoch 66: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1111 - accuracy: 0.9444 - val_loss: 0.1796 - val_accuracy: 0.9144
# Epoch 67/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1113 - accuracy: 0.9444
# Epoch 67: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1113 - accuracy: 0.9444 - val_loss: 0.1987 - val_accuracy: 0.9014
# Epoch 68/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9446
# Epoch 68: val_loss did not improve from 0.12202
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1113 - accuracy: 0.9447 - val_loss: 0.1440 - val_accuracy: 0.9355
# Epoch 69/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1108 - accuracy: 0.9451
# Epoch 69: val_loss improved from 0.12202 to 0.11731, saving model to CNN_dataset_2.h5
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1109 - accuracy: 0.9451 - val_loss: 0.1173 - val_accuracy: 0.9421
# Epoch 70/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1105 - accuracy: 0.9449
# Epoch 70: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1104 - accuracy: 0.9449 - val_loss: 0.1585 - val_accuracy: 0.9180
# Epoch 71/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1097 - accuracy: 0.9457
# Epoch 71: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1098 - accuracy: 0.9456 - val_loss: 0.1600 - val_accuracy: 0.9226
# Epoch 72/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1100 - accuracy: 0.9451
# Epoch 72: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1100 - accuracy: 0.9451 - val_loss: 0.1860 - val_accuracy: 0.9237
# Epoch 73/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1090 - accuracy: 0.9461
# Epoch 73: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1090 - accuracy: 0.9461 - val_loss: 0.1285 - val_accuracy: 0.9420
# Epoch 74/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1090 - accuracy: 0.9458
# Epoch 74: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1090 - accuracy: 0.9458 - val_loss: 0.1196 - val_accuracy: 0.9427
# Epoch 75/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9466
# Epoch 75: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1089 - accuracy: 0.9466 - val_loss: 0.2036 - val_accuracy: 0.9209
# Epoch 76/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1084 - accuracy: 0.9461
# Epoch 76: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1084 - accuracy: 0.9461 - val_loss: 0.2110 - val_accuracy: 0.9165
# Epoch 77/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1084 - accuracy: 0.9458
# Epoch 77: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1083 - accuracy: 0.9459 - val_loss: 0.2017 - val_accuracy: 0.9152
# Epoch 78/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1077 - accuracy: 0.9469
# Epoch 78: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1076 - accuracy: 0.9469 - val_loss: 0.1264 - val_accuracy: 0.9406
# Epoch 79/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1075 - accuracy: 0.9467
# Epoch 79: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1075 - accuracy: 0.9467 - val_loss: 0.1181 - val_accuracy: 0.9426
# Epoch 80/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1071 - accuracy: 0.9472
# Epoch 80: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1071 - accuracy: 0.9472 - val_loss: 0.1393 - val_accuracy: 0.9367
# Epoch 81/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1071 - accuracy: 0.9474
# Epoch 81: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1071 - accuracy: 0.9473 - val_loss: 0.3839 - val_accuracy: 0.8676
# Epoch 82/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1068 - accuracy: 0.9472
# Epoch 82: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1068 - accuracy: 0.9472 - val_loss: 0.1440 - val_accuracy: 0.9354
# Epoch 83/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1067 - accuracy: 0.9472
# Epoch 83: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1067 - accuracy: 0.9472 - val_loss: 0.1798 - val_accuracy: 0.9225
# Epoch 84/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.9477
# Epoch 84: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1064 - accuracy: 0.9477 - val_loss: 0.1626 - val_accuracy: 0.9331
# Epoch 85/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9479
# Epoch 85: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1058 - accuracy: 0.9479 - val_loss: 0.1275 - val_accuracy: 0.9403
# Epoch 86/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9476
# Epoch 86: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1058 - accuracy: 0.9477 - val_loss: 0.1280 - val_accuracy: 0.9410
# Epoch 87/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9478
# Epoch 87: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1052 - accuracy: 0.9478 - val_loss: 0.1356 - val_accuracy: 0.9362
# Epoch 88/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1054 - accuracy: 0.9479
# Epoch 88: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1055 - accuracy: 0.9479 - val_loss: 0.1458 - val_accuracy: 0.9347
# Epoch 89/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.9480
# Epoch 89: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1047 - accuracy: 0.9480 - val_loss: 0.1395 - val_accuracy: 0.9319
# Epoch 90/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1041 - accuracy: 0.9485
# Epoch 90: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1041 - accuracy: 0.9485 - val_loss: 0.1895 - val_accuracy: 0.9249
# Epoch 91/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.9482
# Epoch 91: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1047 - accuracy: 0.9482 - val_loss: 0.1343 - val_accuracy: 0.9378
# Epoch 92/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1022 - accuracy: 0.9496
# Epoch 92: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1021 - accuracy: 0.9497 - val_loss: 0.1556 - val_accuracy: 0.9295
# Epoch 93/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1026 - accuracy: 0.9498
# Epoch 93: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1026 - accuracy: 0.9498 - val_loss: 0.1425 - val_accuracy: 0.9407
# Epoch 94/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9492
# Epoch 94: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1033 - accuracy: 0.9492 - val_loss: 0.2275 - val_accuracy: 0.9155
# Epoch 95/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1026 - accuracy: 0.9494
# Epoch 95: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1026 - accuracy: 0.9494 - val_loss: 0.1205 - val_accuracy: 0.9412
# Epoch 96/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1027 - accuracy: 0.9493
# Epoch 96: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1028 - accuracy: 0.9493 - val_loss: 0.1386 - val_accuracy: 0.9342
# Epoch 97/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1022 - accuracy: 0.9496
# Epoch 97: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1022 - accuracy: 0.9495 - val_loss: 0.1282 - val_accuracy: 0.9381
# Epoch 98/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1023 - accuracy: 0.9494
# Epoch 98: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1023 - accuracy: 0.9494 - val_loss: 0.1290 - val_accuracy: 0.9391
# Epoch 99/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1022 - accuracy: 0.9496
# Epoch 99: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1022 - accuracy: 0.9496 - val_loss: 0.1771 - val_accuracy: 0.9235
# Epoch 100/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1019 - accuracy: 0.9496
# Epoch 100: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1019 - accuracy: 0.9496 - val_loss: 0.1213 - val_accuracy: 0.9423
# Epoch 101/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1018 - accuracy: 0.9499
# Epoch 101: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.1018 - accuracy: 0.9499 - val_loss: 0.1456 - val_accuracy: 0.9343
# Epoch 102/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1012 - accuracy: 0.9500
# Epoch 102: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1013 - accuracy: 0.9500 - val_loss: 0.1303 - val_accuracy: 0.9375
# Epoch 103/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.1004 - accuracy: 0.9503
# Epoch 103: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.1004 - accuracy: 0.9503 - val_loss: 0.1274 - val_accuracy: 0.9391
# Epoch 104/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9506
# Epoch 104: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0998 - accuracy: 0.9506 - val_loss: 0.1378 - val_accuracy: 0.9369
# Epoch 105/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.9509
# Epoch 105: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0997 - accuracy: 0.9509 - val_loss: 0.1241 - val_accuracy: 0.9417
# Epoch 106/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9508
# Epoch 106: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0998 - accuracy: 0.9508 - val_loss: 0.1948 - val_accuracy: 0.9227
# Epoch 107/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0993 - accuracy: 0.9509
# Epoch 107: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0992 - accuracy: 0.9510 - val_loss: 0.1585 - val_accuracy: 0.9280
# Epoch 108/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0988 - accuracy: 0.9519
# Epoch 108: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0988 - accuracy: 0.9519 - val_loss: 0.1269 - val_accuracy: 0.9389
# Epoch 109/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0984 - accuracy: 0.9516
# Epoch 109: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0984 - accuracy: 0.9516 - val_loss: 0.2057 - val_accuracy: 0.9263
# Epoch 110/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0980 - accuracy: 0.9518
# Epoch 110: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0980 - accuracy: 0.9518 - val_loss: 0.1313 - val_accuracy: 0.9395
# Epoch 111/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0984 - accuracy: 0.9516
# Epoch 111: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0984 - accuracy: 0.9516 - val_loss: 0.1763 - val_accuracy: 0.9255
# Epoch 112/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0982 - accuracy: 0.9516
# Epoch 112: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0981 - accuracy: 0.9516 - val_loss: 0.1460 - val_accuracy: 0.9338
# Epoch 113/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0985 - accuracy: 0.9515
# Epoch 113: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0985 - accuracy: 0.9515 - val_loss: 0.1383 - val_accuracy: 0.9381
# Epoch 114/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0980 - accuracy: 0.9517
# Epoch 114: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0979 - accuracy: 0.9518 - val_loss: 0.1481 - val_accuracy: 0.9302
# Epoch 115/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0975 - accuracy: 0.9523
# Epoch 115: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0975 - accuracy: 0.9523 - val_loss: 0.1505 - val_accuracy: 0.9319
# Epoch 116/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0975 - accuracy: 0.9519
# Epoch 116: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0975 - accuracy: 0.9519 - val_loss: 0.3485 - val_accuracy: 0.8953
# Epoch 117/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9529
# Epoch 117: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0961 - accuracy: 0.9529 - val_loss: 0.1191 - val_accuracy: 0.9443
# Epoch 118/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0965 - accuracy: 0.9524
# Epoch 118: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0965 - accuracy: 0.9524 - val_loss: 0.1208 - val_accuracy: 0.9418
# Epoch 119/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0960 - accuracy: 0.9529
# Epoch 119: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0960 - accuracy: 0.9529 - val_loss: 0.1353 - val_accuracy: 0.9364
# Epoch 120/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0963 - accuracy: 0.9526
# Epoch 120: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0963 - accuracy: 0.9526 - val_loss: 0.2923 - val_accuracy: 0.8915
# Epoch 121/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0955 - accuracy: 0.9527
# Epoch 121: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0955 - accuracy: 0.9527 - val_loss: 0.1297 - val_accuracy: 0.9390
# Epoch 122/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0954 - accuracy: 0.9532
# Epoch 122: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0954 - accuracy: 0.9532 - val_loss: 0.1192 - val_accuracy: 0.9442
# Epoch 123/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0953 - accuracy: 0.9533
# Epoch 123: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0953 - accuracy: 0.9533 - val_loss: 0.1338 - val_accuracy: 0.9390
# Epoch 124/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0947 - accuracy: 0.9531
# Epoch 124: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0947 - accuracy: 0.9532 - val_loss: 0.1901 - val_accuracy: 0.9164
# Epoch 125/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0940 - accuracy: 0.9538
# Epoch 125: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0941 - accuracy: 0.9537 - val_loss: 0.1903 - val_accuracy: 0.9270
# Epoch 126/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0934 - accuracy: 0.9540
# Epoch 126: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0935 - accuracy: 0.9540 - val_loss: 0.3868 - val_accuracy: 0.8955
# Epoch 127/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0928 - accuracy: 0.9546
# Epoch 127: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0928 - accuracy: 0.9546 - val_loss: 0.1365 - val_accuracy: 0.9347
# Epoch 128/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0932 - accuracy: 0.9543
# Epoch 128: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0933 - accuracy: 0.9543 - val_loss: 0.2174 - val_accuracy: 0.9235
# Epoch 129/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0933 - accuracy: 0.9539
# Epoch 129: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0933 - accuracy: 0.9539 - val_loss: 0.1225 - val_accuracy: 0.9442
# Epoch 130/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0929 - accuracy: 0.9545
# Epoch 130: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0929 - accuracy: 0.9545 - val_loss: 0.1387 - val_accuracy: 0.9364
# Epoch 131/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0929 - accuracy: 0.9542
# Epoch 131: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0929 - accuracy: 0.9542 - val_loss: 0.1246 - val_accuracy: 0.9426
# Epoch 132/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0924 - accuracy: 0.9545
# Epoch 132: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0924 - accuracy: 0.9545 - val_loss: 0.1411 - val_accuracy: 0.9310
# Epoch 133/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0923 - accuracy: 0.9547
# Epoch 133: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0922 - accuracy: 0.9547 - val_loss: 0.2318 - val_accuracy: 0.9117
# Epoch 134/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0916 - accuracy: 0.9548
# Epoch 134: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0916 - accuracy: 0.9548 - val_loss: 0.1799 - val_accuracy: 0.9346
# Epoch 135/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0917 - accuracy: 0.9551
# Epoch 135: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0917 - accuracy: 0.9551 - val_loss: 0.1998 - val_accuracy: 0.9175
# Epoch 136/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0917 - accuracy: 0.9547
# Epoch 136: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0918 - accuracy: 0.9547 - val_loss: 0.1249 - val_accuracy: 0.9439
# Epoch 137/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0910 - accuracy: 0.9554
# Epoch 137: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0909 - accuracy: 0.9554 - val_loss: 0.1315 - val_accuracy: 0.9405
# Epoch 138/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0907 - accuracy: 0.9556
# Epoch 138: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0907 - accuracy: 0.9556 - val_loss: 0.1235 - val_accuracy: 0.9434
# Epoch 139/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0905 - accuracy: 0.9553
# Epoch 139: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0906 - accuracy: 0.9553 - val_loss: 0.1947 - val_accuracy: 0.9222
# Epoch 140/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0907 - accuracy: 0.9557
# Epoch 140: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0907 - accuracy: 0.9557 - val_loss: 0.1499 - val_accuracy: 0.9333
# Epoch 141/500
# 688/688 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9557
# Epoch 141: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0901 - accuracy: 0.9557 - val_loss: 0.1546 - val_accuracy: 0.9384
# Epoch 142/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0901 - accuracy: 0.9558
# Epoch 142: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0901 - accuracy: 0.9558 - val_loss: 0.1291 - val_accuracy: 0.9428
# Epoch 143/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0899 - accuracy: 0.9559
# Epoch 143: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0898 - accuracy: 0.9559 - val_loss: 0.1585 - val_accuracy: 0.9359
# Epoch 144/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0898 - accuracy: 0.9563
# Epoch 144: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0897 - accuracy: 0.9563 - val_loss: 0.1876 - val_accuracy: 0.9259
# Epoch 145/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0892 - accuracy: 0.9564
# Epoch 145: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0892 - accuracy: 0.9564 - val_loss: 0.1347 - val_accuracy: 0.9401
# Epoch 146/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0887 - accuracy: 0.9565
# Epoch 146: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0888 - accuracy: 0.9565 - val_loss: 0.1936 - val_accuracy: 0.9204
# Epoch 147/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0873 - accuracy: 0.9570
# Epoch 147: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0873 - accuracy: 0.9570 - val_loss: 0.1680 - val_accuracy: 0.9327
# Epoch 148/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0874 - accuracy: 0.9572
# Epoch 148: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0874 - accuracy: 0.9572 - val_loss: 0.1422 - val_accuracy: 0.9404
# Epoch 149/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0878 - accuracy: 0.9566
# Epoch 149: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0878 - accuracy: 0.9566 - val_loss: 0.1372 - val_accuracy: 0.9439
# Epoch 150/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9573
# Epoch 150: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0871 - accuracy: 0.9573 - val_loss: 0.1242 - val_accuracy: 0.9444
# Epoch 151/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0868 - accuracy: 0.9576
# Epoch 151: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0868 - accuracy: 0.9576 - val_loss: 0.2745 - val_accuracy: 0.9188
# Epoch 152/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0869 - accuracy: 0.9579
# Epoch 152: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0869 - accuracy: 0.9579 - val_loss: 0.1456 - val_accuracy: 0.9414
# Epoch 153/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0864 - accuracy: 0.9578
# Epoch 153: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0864 - accuracy: 0.9578 - val_loss: 0.1352 - val_accuracy: 0.9431
# Epoch 154/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0865 - accuracy: 0.9577
# Epoch 154: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0864 - accuracy: 0.9577 - val_loss: 0.1375 - val_accuracy: 0.9423
# Epoch 155/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9582
# Epoch 155: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0860 - accuracy: 0.9582 - val_loss: 0.1678 - val_accuracy: 0.9266
# Epoch 156/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9589
# Epoch 156: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0841 - accuracy: 0.9589 - val_loss: 0.2039 - val_accuracy: 0.9260
# Epoch 157/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0847 - accuracy: 0.9586
# Epoch 157: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0847 - accuracy: 0.9586 - val_loss: 0.1515 - val_accuracy: 0.9372
# Epoch 158/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0840 - accuracy: 0.9588
# Epoch 158: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0840 - accuracy: 0.9588 - val_loss: 0.1248 - val_accuracy: 0.9441
# Epoch 159/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9589
# Epoch 159: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0839 - accuracy: 0.9589 - val_loss: 0.1871 - val_accuracy: 0.9293
# Epoch 160/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0849 - accuracy: 0.9587
# Epoch 160: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0849 - accuracy: 0.9587 - val_loss: 0.1900 - val_accuracy: 0.9287
# Epoch 161/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0840 - accuracy: 0.9589
# Epoch 161: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0840 - accuracy: 0.9589 - val_loss: 0.1571 - val_accuracy: 0.9376
# Epoch 162/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9590
# Epoch 162: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0841 - accuracy: 0.9590 - val_loss: 0.1309 - val_accuracy: 0.9438
# Epoch 163/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9592
# Epoch 163: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0838 - accuracy: 0.9592 - val_loss: 0.1574 - val_accuracy: 0.9393
# Epoch 164/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0828 - accuracy: 0.9598
# Epoch 164: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0828 - accuracy: 0.9598 - val_loss: 0.1708 - val_accuracy: 0.9381
# Epoch 165/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9596
# Epoch 165: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0829 - accuracy: 0.9596 - val_loss: 0.2146 - val_accuracy: 0.9250
# Epoch 166/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9596
# Epoch 166: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0829 - accuracy: 0.9597 - val_loss: 0.1752 - val_accuracy: 0.9340
# Epoch 167/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9601
# Epoch 167: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0825 - accuracy: 0.9601 - val_loss: 0.1358 - val_accuracy: 0.9425
# Epoch 168/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0830 - accuracy: 0.9597
# Epoch 168: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0830 - accuracy: 0.9597 - val_loss: 0.1431 - val_accuracy: 0.9393
# Epoch 169/500
# 688/688 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9594
# Epoch 169: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0828 - accuracy: 0.9594 - val_loss: 0.1507 - val_accuracy: 0.9410
# Epoch 170/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9598
# Epoch 170: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0823 - accuracy: 0.9598 - val_loss: 0.1392 - val_accuracy: 0.9424
# Epoch 171/500
# ...
# Epoch 444: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0442 - accuracy: 0.9786 - val_loss: 0.2254 - val_accuracy: 0.9430
# Epoch 445/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0451 - accuracy: 0.9780
# Epoch 445: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0451 - accuracy: 0.9780 - val_loss: 0.2518 - val_accuracy: 0.9359
# Epoch 446/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0459 - accuracy: 0.9778
# Epoch 446: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0459 - accuracy: 0.9778 - val_loss: 0.2246 - val_accuracy: 0.9428
# Epoch 447/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0449 - accuracy: 0.9782
# Epoch 447: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0449 - accuracy: 0.9781 - val_loss: 0.2202 - val_accuracy: 0.9414
# Epoch 448/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9783
# Epoch 448: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0455 - accuracy: 0.9783 - val_loss: 0.3124 - val_accuracy: 0.9312
# Epoch 449/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9780
# Epoch 449: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0455 - accuracy: 0.9780 - val_loss: 0.2326 - val_accuracy: 0.9422
# Epoch 450/500
# 688/688 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9788
# Epoch 450: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0436 - accuracy: 0.9788 - val_loss: 0.3345 - val_accuracy: 0.9295
# Epoch 451/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9782
# Epoch 451: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0448 - accuracy: 0.9782 - val_loss: 0.2237 - val_accuracy: 0.9414
# Epoch 452/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9784
# Epoch 452: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0452 - accuracy: 0.9784 - val_loss: 0.4801 - val_accuracy: 0.9248
# Epoch 453/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0466 - accuracy: 0.9777
# Epoch 453: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0466 - accuracy: 0.9778 - val_loss: 0.2310 - val_accuracy: 0.9410
# Epoch 454/500
# 688/688 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9787
# Epoch 454: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0445 - accuracy: 0.9787 - val_loss: 0.2320 - val_accuracy: 0.9438
# Epoch 455/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9790
# Epoch 455: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0434 - accuracy: 0.9789 - val_loss: 0.2349 - val_accuracy: 0.9440
# Epoch 456/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0445 - accuracy: 0.9783
# Epoch 456: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0445 - accuracy: 0.9783 - val_loss: 0.2309 - val_accuracy: 0.9428
# Epoch 457/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9788
# Epoch 457: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0443 - accuracy: 0.9789 - val_loss: 0.2447 - val_accuracy: 0.9353
# Epoch 458/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9788
# Epoch 458: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0443 - accuracy: 0.9788 - val_loss: 0.2185 - val_accuracy: 0.9389
# Epoch 459/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9788
# Epoch 459: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0443 - accuracy: 0.9788 - val_loss: 0.2727 - val_accuracy: 0.9405
# Epoch 460/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9785
# Epoch 460: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0443 - accuracy: 0.9784 - val_loss: 0.2298 - val_accuracy: 0.9391
# Epoch 461/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0450 - accuracy: 0.9783
# Epoch 461: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0450 - accuracy: 0.9784 - val_loss: 0.4522 - val_accuracy: 0.9220
# Epoch 462/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9793
# Epoch 462: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0432 - accuracy: 0.9793 - val_loss: 0.2384 - val_accuracy: 0.9422
# Epoch 463/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0434 - accuracy: 0.9790
# Epoch 463: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0435 - accuracy: 0.9790 - val_loss: 0.2631 - val_accuracy: 0.9423
# Epoch 464/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9785
# Epoch 464: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0452 - accuracy: 0.9785 - val_loss: 0.2443 - val_accuracy: 0.9427
# Epoch 465/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0447 - accuracy: 0.9782
# Epoch 465: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0448 - accuracy: 0.9782 - val_loss: 0.2491 - val_accuracy: 0.9420
# Epoch 466/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9790
# Epoch 466: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0433 - accuracy: 0.9790 - val_loss: 0.3371 - val_accuracy: 0.9357
# Epoch 467/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9789
# Epoch 467: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0436 - accuracy: 0.9789 - val_loss: 0.2211 - val_accuracy: 0.9420
# Epoch 468/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9786
# Epoch 468: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0442 - accuracy: 0.9787 - val_loss: 0.2291 - val_accuracy: 0.9422
# Epoch 469/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0450 - accuracy: 0.9785
# Epoch 469: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0450 - accuracy: 0.9785 - val_loss: 0.4417 - val_accuracy: 0.9223
# Epoch 470/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9790
# Epoch 470: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0436 - accuracy: 0.9789 - val_loss: 0.2338 - val_accuracy: 0.9381
# Epoch 471/500
# 686/688 [============================>.] - ETA: 0s - loss: 0.0434 - accuracy: 0.9790
# Epoch 471: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0435 - accuracy: 0.9790 - val_loss: 0.2309 - val_accuracy: 0.9415
# Epoch 472/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9800
# Epoch 472: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0416 - accuracy: 0.9800 - val_loss: 0.4535 - val_accuracy: 0.9219
# Epoch 473/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0432 - accuracy: 0.9793
# Epoch 473: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0432 - accuracy: 0.9793 - val_loss: 0.4707 - val_accuracy: 0.9253
# Epoch 474/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9791
# Epoch 474: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0435 - accuracy: 0.9791 - val_loss: 0.2685 - val_accuracy: 0.9315
# Epoch 475/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9790
# Epoch 475: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0437 - accuracy: 0.9789 - val_loss: 0.2682 - val_accuracy: 0.9396
# Epoch 476/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9790
# Epoch 476: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0435 - accuracy: 0.9790 - val_loss: 0.4136 - val_accuracy: 0.9257
# Epoch 477/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0441 - accuracy: 0.9786
# Epoch 477: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0441 - accuracy: 0.9786 - val_loss: 0.2379 - val_accuracy: 0.9334
# Epoch 478/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9787
# Epoch 478: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0438 - accuracy: 0.9787 - val_loss: 0.2339 - val_accuracy: 0.9430
# Epoch 479/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9792
# Epoch 479: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0436 - accuracy: 0.9792 - val_loss: 0.2477 - val_accuracy: 0.9417
# Epoch 480/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0431 - accuracy: 0.9792
# Epoch 480: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0431 - accuracy: 0.9792 - val_loss: 0.4252 - val_accuracy: 0.9254
# Epoch 481/500
# 688/688 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9789
# Epoch 481: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0442 - accuracy: 0.9789 - val_loss: 0.2344 - val_accuracy: 0.9422
# Epoch 482/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9789
# Epoch 482: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0434 - accuracy: 0.9789 - val_loss: 0.2273 - val_accuracy: 0.9413
# Epoch 483/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0432 - accuracy: 0.9793
# Epoch 483: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0432 - accuracy: 0.9793 - val_loss: 0.2455 - val_accuracy: 0.9416
# Epoch 484/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9800
# Epoch 484: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0414 - accuracy: 0.9800 - val_loss: 0.3247 - val_accuracy: 0.9346
# Epoch 485/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9802
# Epoch 485: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0415 - accuracy: 0.9802 - val_loss: 0.2633 - val_accuracy: 0.9396
# Epoch 486/500
# 687/688 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9789
# Epoch 486: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0438 - accuracy: 0.9789 - val_loss: 0.3100 - val_accuracy: 0.9322
# Epoch 487/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9791
# Epoch 487: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0435 - accuracy: 0.9791 - val_loss: 0.5448 - val_accuracy: 0.9193
# Epoch 488/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0429 - accuracy: 0.9792
# Epoch 488: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0429 - accuracy: 0.9792 - val_loss: 0.2520 - val_accuracy: 0.9358
# Epoch 489/500
# 688/688 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9789
# Epoch 489: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0437 - accuracy: 0.9789 - val_loss: 0.2263 - val_accuracy: 0.9428
# Epoch 490/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9795
# Epoch 490: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0423 - accuracy: 0.9795 - val_loss: 0.2551 - val_accuracy: 0.9337
# Epoch 491/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9788
# Epoch 491: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 15ms/step - loss: 0.0443 - accuracy: 0.9788 - val_loss: 0.2298 - val_accuracy: 0.9404
# Epoch 492/500
# 687/688 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9792
# Epoch 492: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0436 - accuracy: 0.9792 - val_loss: 0.3332 - val_accuracy: 0.9308
# Epoch 493/500
# 688/688 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9800
# Epoch 493: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0417 - accuracy: 0.9800 - val_loss: 0.2477 - val_accuracy: 0.9412
# Epoch 494/500
# 688/688 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9798
# Epoch 494: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0425 - accuracy: 0.9798 - val_loss: 0.2452 - val_accuracy: 0.9412
# Epoch 495/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9796
# Epoch 495: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0428 - accuracy: 0.9796 - val_loss: 0.2840 - val_accuracy: 0.9412
# Epoch 496/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0432 - accuracy: 0.9792
# Epoch 496: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0432 - accuracy: 0.9792 - val_loss: 0.2965 - val_accuracy: 0.9347
# Epoch 497/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9796
# Epoch 497: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0428 - accuracy: 0.9796 - val_loss: 0.3287 - val_accuracy: 0.9340
# Epoch 498/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0434 - accuracy: 0.9791
# Epoch 498: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0434 - accuracy: 0.9791 - val_loss: 0.2589 - val_accuracy: 0.9413
# Epoch 499/500
# 685/688 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.9798
# Epoch 499: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0420 - accuracy: 0.9798 - val_loss: 0.2172 - val_accuracy: 0.9380
# Epoch 500/500
# 684/688 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9795
# Epoch 500: val_loss did not improve from 0.11731
# 688/688 [==============================] - 11s 16ms/step - loss: 0.0430 - accuracy: 0.9795 - val_loss: 0.2680 - val_accuracy: 0.9425
# ('Training time=', 5418.63609457016)

# %%
###################### 2
from contextlib import redirect_stdout
with open('./'+name_file+".xls", 'w') as f:
    with redirect_stdout(f):
        CNN_model.summary()

# %%
import pandas as pd
log_data = pd.read_csv('./training.log', sep=',', engine='python')
#print (log_data)
CNN =log_data

# %%
print (name_file)
# Out:
# CNN_dataset_2

# %%
import numpy as np
CNN11_history_11=np.load('./CNN_data_2_@history.npy',allow_pickle='TRUE').item()

# %%
from keras.models import load_model
####################### 1
name_file11 = './CNN_dataset_2.h5' 
fashion_model = load_model(name_file11) # load model
fashion_model.summary() # summarize model.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1, 16, 512)        5120
#
#  batch_normalization (BatchN  (None, 1, 16, 512)       2048
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 1, 8, 512)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 1, 8, 256)         1179904
#
#  batch_normalization_1 (Batc  (None, 1, 8, 256)        1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 4, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 4, 128)         295040
#
#  conv2d_3 (Conv2D)           (None, 1, 4, 128)         147584
#
#  batch_normalization_2 (Batc  (None, 1, 4, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 2, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 1, 2, 64)          73792
#
#  conv2d_5 (Conv2D)           (None, 1, 2, 64)          36928
#
#  conv2d_6 (Conv2D)           (None, 1, 2, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 1, 2, 64)         256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 1,779,266
# Trainable params: 1,777,346
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
val_loss, val_accuracy=fashion_model.evaluate(X_test ,Y_test) ## to get test accuracy and losses
print(val_loss, val_accuracy)
# Out:
# 1611/1611 [==============================] - 5s 3ms/step - loss: 0.1173 - accuracy: 0.9421
# 0.11730685085058212 0.9421364068984985

# %%
time2=time.time()
predict_prob=fashion_model.predict(X_test)
y_pred=np.argmax(predict_prob,axis=1)
print ('classification time:', time.time()-time2)

##print (y_pred)
y_true=np.argmax(Y_test, axis=1)
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix
CM = confusion_matrix(y_true, y_pred)
print (CM)
print(classification_report(y_true, y_pred))

precision = precision_score(y_test, y_pred, average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred, average='weighted')
print('Recall: %f' % recall)
# f1: tp / (tp + fp + fn)
f1 = f1_score(y_test, y_pred, average='weighted')
print('F1 score: %f' % f1)
#-----------  IoU
from sklearn.metrics import jaccard_score
print ('IoU:', jaccard_score(y_true, y_pred, average='micro'))


test_eval = fashion_model.evaluate(X_test, Y_test)

loss, accuracy = fashion_model.evaluate(X_train, Y_train)
print('loss_train: ', loss, 'accuracy_train: ', accuracy)
print('Test loss:', test_eval[0], 'Test accuracy:', test_eval[1])

TN = CM[0][0]
FN = CM[1][0]
TP = CM[1][1]
FP = CM[0][1]
#================ classification metrics
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
print ('TPR',TPR)   
# Specificity or true negative rate
TNR = TN/(TN+FP) 
print('TNR',TNR)
# Precision or positive predictive value
PPV = TP/(TP+FN)
print ('PPV', PPV)
# Negative predictive value
NPV = TN/(TN+FN)
print('NPV', NPV)
# Fall out or false positive rate
FPR = FP/(FP+TN)
print('FPR',FPR)
# False negative rate
FNR = FN/(TP+FN)
print ('FNR',FNR)  
# False discovery rate
FDR = FP/(TP+FP)
print ('FDR',FDR)    
# Overall accuracy   
ACC = (TP+TN)/(TP+FP+FN+TN)
print ('ACC',ACC)
# Out:
# classification time: 2.839247465133667
# [[17072  1564]
#  [ 1418 31481]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     18636
#            1       0.95      0.96      0.95     32899
#
#     accuracy                           0.94     51535
#    macro avg       0.94      0.94      0.94     51535
# weighted avg       0.94      0.94      0.94     51535
#
# Precision: 0.942053
# Recall: 0.942136
# F1 score: 0.942087
# IoU: 0.8906029311957738
# 1611/1611 [==============================] - 4s 3ms/step - loss: 0.1173 - accuracy: 0.9421
# 6442/6442 [==============================] - 18s 3ms/step - loss: 0.1098 - accuracy: 0.9459
# loss_train:  0.1098375990986824 accuracy_train:  0.9458615183830261
# Test loss: 0.11730685085058212 Test accuracy: 0.9421364068984985
# TPR 0.9568983859691784
# TNR 0.9160764112470487
# PPV 0.9568983859691784
# NPV 0.9233098972417523
# FPR 0.08392358875295128
# FNR 0.043101614030821606
# FDR 0.04732939930397942
# ACC 0.9421364121470845

# %%
history_dict = CNN11_history_11

# %%
#history_dict=cnn11.history
loss_values=history_dict['loss']
val_loss_values=history_dict['val_loss']
acc_values=history_dict['accuracy']
val_acc_values=history_dict['val_accuracy']
epochs=range(1, len(acc_values)+1)
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points
loss_values=smooth_curve(loss_values)
val_loss_values=smooth_curve(val_loss_values)
acc_values=smooth_curve(acc_values)
val_acc_values=smooth_curve(val_acc_values)

font = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'normal',
        'size'   : 12}
        

plt.plot(epochs, acc_values, 'ro', label='Training acc')
plt.plot(epochs, val_acc_values, 'g', label='Validation acc')
plt.title('Training and Validation acc', fontdict=font)
plt.xlabel('Epochs', fontdict=font)
plt.ylabel('Accuracy', fontdict=font)
plt.legend()
plt.savefig("accuracy"+name_file+".png")
plt.show()

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and Validation loss', fontdict=font)
plt.xlabel('Epochs',fontdict=font)
plt.ylabel('Loss',fontdict=font)
plt.legend()
plt.savefig("loss"+name_file+".png")
plt.show()

# %%
class_names = ['Normal','Attack']


def plot_confusion_matrix(y_true, y_pred, classes,normalize=False,title=None, cmap=plt.cm.Reds):
                                              
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = None    ### 'Normalized confusion matrix'
        else:
            title = None        ### 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
#    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    fig, ax = plt.subplots(figsize=(8,8))
    ax.tick_params(labelsize=12)       #7777777777777777777777777777777777777777777777777777
    cmap=plt.cm.Reds                      #  cmap=plt.cm.Blues
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    cbar = ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    for t in cbar.ax.get_yticklabels():
        t.set_fontsize(15)
    
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor")
             
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

font = {'family' : 'Times New Roman',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 15}

np.set_printoptions(precision=2) ########################## 2

# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test, y_pred, classes=class_names,title= None)             
plt.xlabel('Predicted label', fontsize=18)
plt.ylabel('True label', fontsize=18)
plt.savefig('confusion matrix_1_'+name_file+'.png')
plt.show()

# Plot normalized confusion matrix
plot_confusion_matrix(y_test, y_pred, classes=class_names, normalize=True,title=None)            
plt.xlabel('Predicted label', fontsize=18)
plt.ylabel('True label', fontsize=18)
plt.savefig('confusion matrix_2_'+name_file+'.png')
plt.show()
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %%
from IPython.display import FileLink
FileLink(r'./LSTM_dataset_2.h5') #=======================
# Out:
# /content/LSTM_dataset_2.h5
